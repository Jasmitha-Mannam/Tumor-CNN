# %%
# !pip install opencv-python pydicom pandas scikit-learn matplotlib seaborn tensorflow
# Out:
# Requirement already satisfied: opencv-python in c:\users\jasmi\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: pydicom in c:\users\jasmi\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: pandas in c:\users\jasmi\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: scikit-learn in c:\users\jasmi\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: matplotlib in c:\users\jasmi\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: seaborn in c:\users\jasmi\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: tensorflow in c:\users\jasmi\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\jasmi\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jasmi\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jasmi\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jasmi\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\jasmi\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\jasmi\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jasmi\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jasmi\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jasmi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\jasmi\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\jasmi\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\jasmi\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jasmi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jasmi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jasmi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jasmi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jasmi\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jasmi\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\jasmi\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jasmi\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jasmi\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# Function to load images
def load_dataset(folder_path, img_size=128):
    data = []
    labels = []
    class_names = os.listdir(folder_path)
    for class_name in class_names:
        class_path = os.path.join(folder_path, class_name)
        for img_file in os.listdir(class_path):
            img_path = os.path.join(class_path, img_file)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                img = cv2.resize(img, (img_size, img_size))
                data.append(img)
                labels.append(class_name)
    return np.array(data), np.array(labels)

# ⚠️ Use raw string (r'path') for Windows paths
train_folder = r'C:\Users\jasmi\Downloads\archive (2)\Training'
test_folder = r'C:\Users\jasmi\Downloads\archive (2)\Testing'

# Load datasets
x_train, y_train = load_dataset(train_folder)
x_test, y_test = load_dataset(test_folder)

# Normalize
x_train = x_train.reshape(-1, 128, 128, 1) / 255.0
x_test = x_test.reshape(-1, 128, 128, 1) / 255.0

# Encode labels
le = LabelEncoder()
y_train_encoded = to_categorical(le.fit_transform(y_train))
y_test_encoded = to_categorical(le.transform(y_test))

# Check number of classes
num_classes = y_train_encoded.shape[1]

# Build CNN Model
model = Sequential([
    Input(shape=(128, 128, 1)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # number of output classes
])

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train
history = model.fit(x_train, y_train_encoded, epochs=20, validation_data=(x_test, y_test_encoded))

# Evaluate
loss, acc = model.evaluate(x_test, y_test_encoded)
print(f"\nTest Accuracy: {acc * 100:.2f}%")
# Out:
# Epoch 1/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 51s 257ms/step - accuracy: 0.6122 - loss: 0.9325 - val_accuracy: 0.8200 - val_loss: 0.4708
# Epoch 2/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 54s 304ms/step - accuracy: 0.8530 - loss: 0.3912 - val_accuracy: 0.8337 - val_loss: 0.4000
# Epoch 3/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 52s 290ms/step - accuracy: 0.8892 - loss: 0.2894 - val_accuracy: 0.8749 - val_loss: 0.3318
# Epoch 4/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 46s 255ms/step - accuracy: 0.9298 - loss: 0.2038 - val_accuracy: 0.9222 - val_loss: 0.2014
# Epoch 5/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 86s 275ms/step - accuracy: 0.9458 - loss: 0.1493 - val_accuracy: 0.9443 - val_loss: 0.1492
# Epoch 6/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 51s 283ms/step - accuracy: 0.9664 - loss: 0.1050 - val_accuracy: 0.9367 - val_loss: 0.1589
# Epoch 7/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 115s 645ms/step - accuracy: 0.9677 - loss: 0.0908 - val_accuracy: 0.9474 - val_loss: 0.1318
# Epoch 8/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 47s 260ms/step - accuracy: 0.9652 - loss: 0.0873 - val_accuracy: 0.9512 - val_loss: 0.1448
# Epoch 9/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 52s 289ms/step - accuracy: 0.9765 - loss: 0.0652 - val_accuracy: 0.9649 - val_loss: 0.1224
# Epoch 10/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 55s 303ms/step - accuracy: 0.9849 - loss: 0.0493 - val_accuracy: 0.9535 - val_loss: 0.1422
# Epoch 11/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 48s 265ms/step - accuracy: 0.9819 - loss: 0.0468 - val_accuracy: 0.9619 - val_loss: 0.1219
# Epoch 12/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 55s 307ms/step - accuracy: 0.9916 - loss: 0.0286 - val_accuracy: 0.9680 - val_loss: 0.1176
# Epoch 13/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 51s 285ms/step - accuracy: 0.9822 - loss: 0.0459 - val_accuracy: 0.9596 - val_loss: 0.1257
# Epoch 14/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 49s 273ms/step - accuracy: 0.9899 - loss: 0.0367 - val_accuracy: 0.9725 - val_loss: 0.1137
# Epoch 15/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 50s 279ms/step - accuracy: 0.9914 - loss: 0.0315 - val_accuracy: 0.9664 - val_loss: 0.1215
# Epoch 16/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 51s 286ms/step - accuracy: 0.9940 - loss: 0.0233 - val_accuracy: 0.9657 - val_loss: 0.1303
# Epoch 17/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 58s 321ms/step - accuracy: 0.9899 - loss: 0.0295 - val_accuracy: 0.9558 - val_loss: 0.1405
# Epoch 18/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 50s 280ms/step - accuracy: 0.9931 - loss: 0.0222 - val_accuracy: 0.9733 - val_loss: 0.1168
# Epoch 19/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 47s 263ms/step - accuracy: 0.9899 - loss: 0.0316 - val_accuracy: 0.9695 - val_loss: 0.1209
# Epoch 20/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 49s 275ms/step - accuracy: 0.9893 - loss: 0.0298 - val_accuracy: 0.9580 - val_loss: 0.1881
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9259 - loss: 0.3466
#
# Test Accuracy: 95.80%
